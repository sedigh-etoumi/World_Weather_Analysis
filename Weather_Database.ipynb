# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | say
# Processing Record 3 of Set 1 | fez
# Processing Record 4 of Set 1 | batagay
# Processing Record 5 of Set 1 | tarakan
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | marawi
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | huainan
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | homer
# Processing Record 12 of Set 1 | saquarema
# Processing Record 13 of Set 1 | maceio
# Processing Record 14 of Set 1 | hualmay
# Processing Record 15 of Set 1 | kochki
# Processing Record 16 of Set 1 | gillette
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | acapulco
# Processing Record 20 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | makakilo city
# Processing Record 25 of Set 1 | sola
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | solsvik
# City not found. Skipping...
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | dukat
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | matay
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | sabang
# Processing Record 38 of Set 1 | palmer
# Processing Record 39 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 1 | axim
# Processing Record 41 of Set 1 | viedma
# Processing Record 42 of Set 1 | kalemie
# Processing Record 43 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | nelson bay
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | tame
# Processing Record 4 of Set 2 | lompoc
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | kloulklubed
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | alfenas
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | fort nelson
# Processing Record 12 of Set 2 | caravelas
# Processing Record 13 of Set 2 | samarinda
# Processing Record 14 of Set 2 | kununurra
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | beloha
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 2 | hobyo
# Processing Record 22 of Set 2 | hay river
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | bogovarovo
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | geraldton
# Processing Record 28 of Set 2 | massaguet
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | ahipara
# Processing Record 31 of Set 2 | shakawe
# Processing Record 32 of Set 2 | general roca
# Processing Record 33 of Set 2 | hambantota
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | malamig
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | fairbanks
# Processing Record 43 of Set 2 | poya
# Processing Record 44 of Set 2 | kropachevo
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | saint-augustin
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | santa maria
# Processing Record 49 of Set 2 | gayny
# Processing Record 50 of Set 2 | gayeri
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | bluff
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | coahuayana
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | kismayo
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | sao filipe
# Processing Record 11 of Set 3 | bafoulabe
# Processing Record 12 of Set 3 | alice springs
# Processing Record 13 of Set 3 | kidal
# Processing Record 14 of Set 3 | rocha
# Processing Record 15 of Set 3 | cordoba
# Processing Record 16 of Set 3 | mount pleasant
# Processing Record 17 of Set 3 | busselton
# Processing Record 18 of Set 3 | umm lajj
# Processing Record 19 of Set 3 | shirokiy
# Processing Record 20 of Set 3 | codrington
# Processing Record 21 of Set 3 | constantine
# Processing Record 22 of Set 3 | coatlan
# City not found. Skipping...
# Processing Record 23 of Set 3 | kahului
# Processing Record 24 of Set 3 | atherton
# Processing Record 25 of Set 3 | adrar
# Processing Record 26 of Set 3 | tuatapere
# Processing Record 27 of Set 3 | korla
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | arraial do cabo
# Processing Record 30 of Set 3 | mehran
# Processing Record 31 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | itarema
# Processing Record 34 of Set 3 | belyy yar
# Processing Record 35 of Set 3 | palu
# Processing Record 36 of Set 3 | sechura
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 3 | labytnangi
# Processing Record 39 of Set 3 | lakheri
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | jining
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | brun
# Processing Record 44 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 3 | uray
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | muscat
# Processing Record 48 of Set 3 | tual
# Processing Record 49 of Set 3 | kamina
# Processing Record 50 of Set 3 | barrow
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | mehamn
# Processing Record 5 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 4 | xunchang
# Processing Record 7 of Set 4 | avarua
# Processing Record 8 of Set 4 | melbu
# Processing Record 9 of Set 4 | piacabucu
# Processing Record 10 of Set 4 | avera
# Processing Record 11 of Set 4 | grand forks
# Processing Record 12 of Set 4 | padang
# Processing Record 13 of Set 4 | bambous virieux
# City not found. Skipping...
# Processing Record 14 of Set 4 | nordfjordeid
# City not found. Skipping...
# Processing Record 15 of Set 4 | biak
# Processing Record 16 of Set 4 | la peca
# Processing Record 17 of Set 4 | kruisfontein
# Processing Record 18 of Set 4 | vestmannaeyjar
# Processing Record 19 of Set 4 | mangrol
# Processing Record 20 of Set 4 | north bend
# Processing Record 21 of Set 4 | sao joao da barra
# Processing Record 22 of Set 4 | kastamonu
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | paamiut
# Processing Record 25 of Set 4 | bosaso
# Processing Record 26 of Set 4 | brae
# Processing Record 27 of Set 4 | ryotsu
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | haimen
# Processing Record 30 of Set 4 | udachnyy
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | grand gaube
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | dingle
# Processing Record 35 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 4 | pontianak
# Processing Record 37 of Set 4 | ambulu
# Processing Record 38 of Set 4 | shingu
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | luderitz
# Processing Record 41 of Set 4 | casablanca
# Processing Record 42 of Set 4 | takab
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | statesville
# Processing Record 45 of Set 4 | opuwo
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | jhajjar
# Processing Record 48 of Set 4 | rafaela
# Processing Record 49 of Set 4 | taos
# Processing Record 50 of Set 4 | anadyr
# Processing Record 1 of Set 5 | tarko-sale
# Processing Record 2 of Set 5 | cardoso
# Processing Record 3 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | rovaniemi
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | derzhavinsk
# Processing Record 8 of Set 5 | dormidontovka
# Processing Record 9 of Set 5 | ostrovnoy
# Processing Record 10 of Set 5 | altamont
# Processing Record 11 of Set 5 | ust-kan
# Processing Record 12 of Set 5 | shihezi
# Processing Record 13 of Set 5 | nishihara
# Processing Record 14 of Set 5 | yar-sale
# Processing Record 15 of Set 5 | galveston
# Processing Record 16 of Set 5 | westport
# Processing Record 17 of Set 5 | kampot
# Processing Record 18 of Set 5 | buchanan
# Processing Record 19 of Set 5 | saint-pierre
# Processing Record 20 of Set 5 | puerto ayora
# Processing Record 21 of Set 5 | tucupita
# Processing Record 22 of Set 5 | xuddur
# Processing Record 23 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | kutum
# Processing Record 26 of Set 5 | lata
# Processing Record 27 of Set 5 | passo de camaragibe
# Processing Record 28 of Set 5 | laguna
# Processing Record 29 of Set 5 | sitka
# Processing Record 30 of Set 5 | erdenet
# Processing Record 31 of Set 5 | deputatskiy
# Processing Record 32 of Set 5 | iguape
# Processing Record 33 of Set 5 | yulara
# Processing Record 34 of Set 5 | sorland
# Processing Record 35 of Set 5 | mackenzie
# Processing Record 36 of Set 5 | namibe
# Processing Record 37 of Set 5 | hasaki
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | kropotkin
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | baykalovo
# Processing Record 42 of Set 5 | weihe
# Processing Record 43 of Set 5 | yoichi
# Processing Record 44 of Set 5 | carnarvon
# Processing Record 45 of Set 5 | atlantic beach
# Processing Record 46 of Set 5 | okhotsk
# Processing Record 47 of Set 5 | ponta delgada
# Processing Record 48 of Set 5 | dawson creek
# Processing Record 49 of Set 5 | sar-e pul
# Processing Record 50 of Set 5 | half moon bay
# Processing Record 1 of Set 6 | rosetta
# Processing Record 2 of Set 6 | elko
# Processing Record 3 of Set 6 | manaure
# Processing Record 4 of Set 6 | przhevalskoye
# Processing Record 5 of Set 6 | necochea
# Processing Record 6 of Set 6 | khetia
# Processing Record 7 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 6 | la rioja
# Processing Record 9 of Set 6 | ye
# City not found. Skipping...
# Processing Record 10 of Set 6 | flinders
# Processing Record 11 of Set 6 | grindavik
# Processing Record 12 of Set 6 | patna
# Processing Record 13 of Set 6 | el tocuyo
# Processing Record 14 of Set 6 | portland
# Processing Record 15 of Set 6 | tahe
# Processing Record 16 of Set 6 | mackay
# Processing Record 17 of Set 6 | teya
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | bodoco
# City not found. Skipping...
# Processing Record 20 of Set 6 | corsicana
# Processing Record 21 of Set 6 | mujiayingzi
# Processing Record 22 of Set 6 | miraflores
# Processing Record 23 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 6 | flin flon
# Processing Record 25 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 6 | cabedelo
# Processing Record 27 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 6 | alakurtti
# Processing Record 29 of Set 6 | mansa
# Processing Record 30 of Set 6 | casas grandes
# Processing Record 31 of Set 6 | ambilobe
# Processing Record 32 of Set 6 | manoel urbano
# Processing Record 33 of Set 6 | alofi
# Processing Record 34 of Set 6 | bara
# Processing Record 35 of Set 6 | sao miguel do araguaia
# Processing Record 36 of Set 6 | sokoni
# Processing Record 37 of Set 6 | baruun-urt
# Processing Record 38 of Set 6 | sinnamary
# Processing Record 39 of Set 6 | lorengau
# Processing Record 40 of Set 6 | la ronge
# Processing Record 41 of Set 6 | kirakira
# Processing Record 42 of Set 6 | ballinrobe
# Processing Record 43 of Set 6 | charters towers
# Processing Record 44 of Set 6 | coihaique
# Processing Record 45 of Set 6 | yarim
# Processing Record 46 of Set 6 | serebryansk
# Processing Record 47 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 6 | skali
# City not found. Skipping...
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 6 | sagar
# Processing Record 1 of Set 7 | port shepstone
# Processing Record 2 of Set 7 | taber
# Processing Record 3 of Set 7 | sidi ali
# Processing Record 4 of Set 7 | verkhnetulomskiy
# Processing Record 5 of Set 7 | kardailovo
# Processing Record 6 of Set 7 | leningradskiy
# Processing Record 7 of Set 7 | malartic
# Processing Record 8 of Set 7 | koumac
# Processing Record 9 of Set 7 | stejaru
# Processing Record 10 of Set 7 | mount gambier
# Processing Record 11 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 7 | atyrau
# Processing Record 13 of Set 7 | lakota
# Processing Record 14 of Set 7 | chapais
# Processing Record 15 of Set 7 | jumla
# Processing Record 16 of Set 7 | jalu
# Processing Record 17 of Set 7 | namatanai
# Processing Record 18 of Set 7 | nieuw nickerie
# Processing Record 19 of Set 7 | lakes entrance
# Processing Record 20 of Set 7 | tautira
# Processing Record 21 of Set 7 | adet
# Processing Record 22 of Set 7 | kashin
# Processing Record 23 of Set 7 | alta floresta
# Processing Record 24 of Set 7 | ternate
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | college
# Processing Record 27 of Set 7 | vestmanna
# Processing Record 28 of Set 7 | eskil
# Processing Record 29 of Set 7 | yelkhovka
# Processing Record 30 of Set 7 | mandalgovi
# Processing Record 31 of Set 7 | zion
# Processing Record 32 of Set 7 | stege
# Processing Record 33 of Set 7 | zyryanka
# Processing Record 34 of Set 7 | hami
# Processing Record 35 of Set 7 | bako
# Processing Record 36 of Set 7 | carauari
# Processing Record 37 of Set 7 | dzilam gonzalez
# Processing Record 38 of Set 7 | port pirie
# Processing Record 39 of Set 7 | labuhan
# Processing Record 40 of Set 7 | petropavl
# Processing Record 41 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 7 | glendive
# Processing Record 43 of Set 7 | torbay
# Processing Record 44 of Set 7 | hun
# Processing Record 45 of Set 7 | tromso
# Processing Record 46 of Set 7 | nizhneudinsk
# Processing Record 47 of Set 7 | iralaya
# Processing Record 48 of Set 7 | antofagasta
# Processing Record 49 of Set 7 | constitucion
# Processing Record 50 of Set 7 | hofn
# Processing Record 1 of Set 8 | saint george
# Processing Record 2 of Set 8 | sainte-thecle
# Processing Record 3 of Set 8 | noumea
# Processing Record 4 of Set 8 | severomuysk
# Processing Record 5 of Set 8 | lavrentiya
# Processing Record 6 of Set 8 | port blair
# Processing Record 7 of Set 8 | grand-santi
# Processing Record 8 of Set 8 | bukachacha
# Processing Record 9 of Set 8 | bonavista
# Processing Record 10 of Set 8 | pechenga
# Processing Record 11 of Set 8 | general teran
# Processing Record 12 of Set 8 | sao felix do xingu
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | colquiri
# Processing Record 16 of Set 8 | olafsvik
# Processing Record 17 of Set 8 | uruguaiana
# Processing Record 18 of Set 8 | werda
# Processing Record 19 of Set 8 | roma
# Processing Record 20 of Set 8 | tyukalinsk
# Processing Record 21 of Set 8 | wilmington
# Processing Record 22 of Set 8 | zhucheng
# Processing Record 23 of Set 8 | bandundu
# Processing Record 24 of Set 8 | chernaya kholunitsa
# Processing Record 25 of Set 8 | praia
# Processing Record 26 of Set 8 | nyurba
# Processing Record 27 of Set 8 | khovu-aksy
# Processing Record 28 of Set 8 | sisimiut
# Processing Record 29 of Set 8 | rawson
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | fortuna
# Processing Record 32 of Set 8 | kalga
# Processing Record 33 of Set 8 | puerto escondido
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | narsaq
# Processing Record 36 of Set 8 | kabanjahe
# Processing Record 37 of Set 8 | shibarghan
# City not found. Skipping...
# Processing Record 38 of Set 8 | norden
# Processing Record 39 of Set 8 | puerto montt
# Processing Record 40 of Set 8 | yantarnyy
# Processing Record 41 of Set 8 | starkville
# Processing Record 42 of Set 8 | calabozo
# Processing Record 43 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 8 | oktyabrskiy
# Processing Record 45 of Set 8 | shache
# Processing Record 46 of Set 8 | henties bay
# Processing Record 47 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 8 | abu samrah
# Processing Record 49 of Set 8 | camacha
# Processing Record 50 of Set 8 | bela
# Processing Record 1 of Set 9 | gat
# Processing Record 2 of Set 9 | pevek
# Processing Record 3 of Set 9 | moree
# Processing Record 4 of Set 9 | saint-georges
# Processing Record 5 of Set 9 | waingapu
# Processing Record 6 of Set 9 | formosa
# Processing Record 7 of Set 9 | arkhangelsk
# Processing Record 8 of Set 9 | pacific grove
# Processing Record 9 of Set 9 | broken hill
# Processing Record 10 of Set 9 | miranda
# Processing Record 11 of Set 9 | bang saphan
# Processing Record 12 of Set 9 | berlevag
# Processing Record 13 of Set 9 | bima
# Processing Record 14 of Set 9 | houma
# Processing Record 15 of Set 9 | turukhansk
# Processing Record 16 of Set 9 | iqaluit
# Processing Record 17 of Set 9 | bubaque
# Processing Record 18 of Set 9 | wagrowiec
# Processing Record 19 of Set 9 | balabac
# Processing Record 20 of Set 9 | komsomolskiy
# Processing Record 21 of Set 9 | quatre cocos
# Processing Record 22 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 24 of Set 9 | beringovskiy
# Processing Record 25 of Set 9 | dolores
# Processing Record 26 of Set 9 | kulgam
# Processing Record 27 of Set 9 | zhuzhou
# Processing Record 28 of Set 9 | lodja
# Processing Record 29 of Set 9 | abu dhabi
# Processing Record 30 of Set 9 | saraland
# Processing Record 31 of Set 9 | podgorodnyaya pokrovka
# Processing Record 32 of Set 9 | sydney
# Processing Record 33 of Set 9 | bahia honda
# Processing Record 34 of Set 9 | fuerte
# Processing Record 35 of Set 9 | husavik
# Processing Record 36 of Set 9 | salalah
# Processing Record 37 of Set 9 | basavana bagevadi
# Processing Record 38 of Set 9 | ratnagiri
# Processing Record 39 of Set 9 | lowestoft
# Processing Record 40 of Set 9 | port augusta
# Processing Record 41 of Set 9 | port hardy
# Processing Record 42 of Set 9 | forbes
# Processing Record 43 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 9 | kalianget
# Processing Record 45 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 46 of Set 9 | okha
# Processing Record 47 of Set 9 | nantucket
# Processing Record 48 of Set 9 | tefe
# Processing Record 49 of Set 9 | baturaja
# Processing Record 50 of Set 9 | altea
# Processing Record 1 of Set 10 | klaksvik
# Processing Record 2 of Set 10 | kapit
# Processing Record 3 of Set 10 | valley city
# Processing Record 4 of Set 10 | mitsamiouli
# Processing Record 5 of Set 10 | ambon
# Processing Record 6 of Set 10 | emirdag
# Processing Record 7 of Set 10 | walvis bay
# Processing Record 8 of Set 10 | jishu
# Processing Record 9 of Set 10 | ostersund
# Processing Record 10 of Set 10 | kaupanger
# Processing Record 11 of Set 10 | dudinka
# Processing Record 12 of Set 10 | vilhena
# Processing Record 13 of Set 10 | conceicao da barra
# Processing Record 14 of Set 10 | qostanay
# Processing Record 15 of Set 10 | santa cruz
# Processing Record 16 of Set 10 | bria
# Processing Record 17 of Set 10 | cabo san lucas
# Processing Record 18 of Set 10 | atasu
# Processing Record 19 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 10 | guerrero negro
# Processing Record 21 of Set 10 | middelburg
# Processing Record 22 of Set 10 | abancay
# Processing Record 23 of Set 10 | baykit
# Processing Record 24 of Set 10 | kaeo
# Processing Record 25 of Set 10 | carutapera
# Processing Record 26 of Set 10 | isangel
# Processing Record 27 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 10 | saint-jovite
# Processing Record 29 of Set 10 | ayan
# Processing Record 30 of Set 10 | qandala
# Processing Record 31 of Set 10 | saint anthony
# Processing Record 32 of Set 10 | tyrma
# Processing Record 33 of Set 10 | tocopilla
# Processing Record 34 of Set 10 | sur
# Processing Record 35 of Set 10 | naze
# Processing Record 36 of Set 10 | fonte boa
# Processing Record 37 of Set 10 | zhezkazgan
# Processing Record 38 of Set 10 | dulao
# Processing Record 39 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 10 | mangan
# Processing Record 41 of Set 10 | iberia
# Processing Record 42 of Set 10 | shenkursk
# Processing Record 43 of Set 10 | phanat nikhom
# Processing Record 44 of Set 10 | obo
# Processing Record 45 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 46 of Set 10 | marsh harbour
# Processing Record 47 of Set 10 | barbate
# Processing Record 48 of Set 10 | bontang
# Processing Record 49 of Set 10 | magnor
# Processing Record 50 of Set 10 | slavsk
# Processing Record 1 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 11 | dawei
# Processing Record 3 of Set 11 | juanjui
# Processing Record 4 of Set 11 | haines junction
# Processing Record 5 of Set 11 | amapa
# Processing Record 6 of Set 11 | torit
# Processing Record 7 of Set 11 | kemi
# Processing Record 8 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 11 | aklavik
# Processing Record 10 of Set 11 | esil
# Processing Record 11 of Set 11 | ust-kuyga
# Processing Record 12 of Set 11 | wangqing
# Processing Record 13 of Set 11 | bawku
# Processing Record 14 of Set 11 | la seyne-sur-mer
# Processing Record 15 of Set 11 | marion
# Processing Record 16 of Set 11 | gombong
# Processing Record 17 of Set 11 | kattivakkam
# Processing Record 18 of Set 11 | marienburg
# Processing Record 19 of Set 11 | san policarpo
# Processing Record 20 of Set 11 | morro bay
# Processing Record 21 of Set 11 | awbari
# Processing Record 22 of Set 11 | faanui
# Processing Record 23 of Set 11 | senneterre
# Processing Record 24 of Set 11 | gliwice
# Processing Record 25 of Set 11 | harnosand
# Processing Record 26 of Set 11 | guozhen
# Processing Record 27 of Set 11 | marapanim
# Processing Record 28 of Set 11 | melito di porto salvo
# Processing Record 29 of Set 11 | vila franca do campo
# Processing Record 30 of Set 11 | belmonte
# Processing Record 31 of Set 11 | airai
# Processing Record 32 of Set 11 | kiunga
# Processing Record 33 of Set 11 | egvekinot
# Processing Record 34 of Set 11 | manokwari
# Processing Record 35 of Set 11 | livny
# Processing Record 36 of Set 11 | gamba
# Processing Record 37 of Set 11 | guane
# Processing Record 38 of Set 11 | colac
# Processing Record 39 of Set 11 | lagoa
# Processing Record 40 of Set 11 | gorontalo
# Processing Record 41 of Set 11 | dongsheng
# Processing Record 42 of Set 11 | marsala
# Processing Record 43 of Set 11 | kalabo
# Processing Record 44 of Set 11 | ilulissat
# Processing Record 45 of Set 11 | parede
# Processing Record 46 of Set 11 | zmievka
# City not found. Skipping...
# Processing Record 47 of Set 11 | champerico
# Processing Record 48 of Set 11 | hovd
# Processing Record 49 of Set 11 | mount isa
# Processing Record 50 of Set 11 | kasangulu
# Processing Record 1 of Set 12 | zhigansk
# Processing Record 2 of Set 12 | ola
# Processing Record 3 of Set 12 | seminole
# Processing Record 4 of Set 12 | christchurch
# Processing Record 5 of Set 12 | mbaiki
# Processing Record 6 of Set 12 | krasnorechenskiy
# Processing Record 7 of Set 12 | parsons
# Processing Record 8 of Set 12 | gushikawa
# Processing Record 9 of Set 12 | jasper
# Processing Record 10 of Set 12 | banda aceh
# Processing Record 11 of Set 12 | bousso
# Processing Record 12 of Set 12 | itoman
# Processing Record 13 of Set 12 | mercedes
# Processing Record 14 of Set 12 | manavalakurichi
# Processing Record 15 of Set 12 | kodinsk
# Processing Record 16 of Set 12 | verkh-usugli
# Processing Record 17 of Set 12 | la romana
# Processing Record 18 of Set 12 | dalbandin
# Processing Record 19 of Set 12 | talnakh
# Processing Record 20 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 21 of Set 12 | mmabatho
# Processing Record 22 of Set 12 | dabat
# Processing Record 23 of Set 12 | arlit
# Processing Record 24 of Set 12 | comodoro rivadavia
# Processing Record 25 of Set 12 | ribas do rio pardo
# Processing Record 26 of Set 12 | thinadhoo
# Processing Record 27 of Set 12 | kaihua
# Processing Record 28 of Set 12 | plettenberg bay
# Processing Record 29 of Set 12 | laukaa
# Processing Record 30 of Set 12 | tombouctou
# Processing Record 31 of Set 12 | bagdarin
# Processing Record 32 of Set 12 | banjar
# Processing Record 33 of Set 12 | kalmunai
# Processing Record 34 of Set 12 | yatou
# Processing Record 35 of Set 12 | mayo
# Processing Record 36 of Set 12 | ubauro
# Processing Record 37 of Set 12 | tiarei
# Processing Record 38 of Set 12 | saint-joseph
# Processing Record 39 of Set 12 | keti bandar
# Processing Record 40 of Set 12 | araouane
# Processing Record 41 of Set 12 | russkiy aktash
# Processing Record 42 of Set 12 | guilin
# Processing Record 43 of Set 12 | akdagmadeni
# Processing Record 44 of Set 12 | kenora
# Processing Record 45 of Set 12 | talaya
# Processing Record 46 of Set 12 | guicheng
# City not found. Skipping...
# Processing Record 47 of Set 12 | burgeo
# Processing Record 48 of Set 12 | thunder bay
# Processing Record 49 of Set 12 | novikovo
# Processing Record 50 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 13 | shelburne
# Processing Record 2 of Set 13 | aras
# Processing Record 3 of Set 13 | itanagar
# Processing Record 4 of Set 13 | sangar
# Processing Record 5 of Set 13 | karratha
# Processing Record 6 of Set 13 | oriximina
# Processing Record 7 of Set 13 | turtas
# Processing Record 8 of Set 13 | thano bula khan
# City not found. Skipping...
# Processing Record 9 of Set 13 | ixtapa
# Processing Record 10 of Set 13 | tahta
# Processing Record 11 of Set 13 | arrifes
# Processing Record 12 of Set 13 | kharp
# Processing Record 13 of Set 13 | ryazanovskiy
# Processing Record 14 of Set 13 | sembe
# Processing Record 15 of Set 13 | chimoio
# Processing Record 16 of Set 13 | akyab
# Processing Record 17 of Set 13 | tessaoua
# Processing Record 18 of Set 13 | damulog
# Processing Record 19 of Set 13 | xiangdong
# City not found. Skipping...
# Processing Record 20 of Set 13 | zhuhai
# Processing Record 21 of Set 13 | kargasok
# Processing Record 22 of Set 13 | lasa
# Processing Record 23 of Set 13 | buala
# Processing Record 24 of Set 13 | lunsar
# Processing Record 25 of Set 13 | malakal
# Processing Record 26 of Set 13 | katherine
# Processing Record 27 of Set 13 | port townsend
# Processing Record 28 of Set 13 | wabrzezno
# Processing Record 29 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 30 of Set 13 | mildura
# Processing Record 31 of Set 13 | aksu
# Processing Record 32 of Set 13 | salamanca
# Processing Record 33 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 13 | villa rica
# Processing Record 35 of Set 13 | souillac
# Processing Record 36 of Set 13 | marzuq
# Processing Record 37 of Set 13 | muzaffarabad
# Processing Record 38 of Set 13 | atambua
# Processing Record 39 of Set 13 | chimbarongo
# Processing Record 40 of Set 13 | abu zabad
# Processing Record 41 of Set 13 | vila velha
# Processing Record 42 of Set 13 | coos bay
# Processing Record 43 of Set 13 | waipawa
# Processing Record 44 of Set 13 | bulgan
# Processing Record 45 of Set 13 | komatipoort
# Processing Record 46 of Set 13 | casper
# Processing Record 47 of Set 13 | coquimbo
# Processing Record 48 of Set 13 | crotone
# Processing Record 49 of Set 13 | maragogi
# Processing Record 50 of Set 13 | arman
# Processing Record 1 of Set 14 | seydi
# Processing Record 2 of Set 14 | plymouth
# Processing Record 3 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 14 | kasongo-lunda
# Processing Record 5 of Set 14 | bumba
# Processing Record 6 of Set 14 | inhambane
# Processing Record 7 of Set 14 | izhma
# Processing Record 8 of Set 14 | mezen
# Processing Record 9 of Set 14 | richards bay
# Processing Record 10 of Set 14 | praya
# Processing Record 11 of Set 14 | bambanglipuro
# Processing Record 12 of Set 14 | mont-dore
# Processing Record 13 of Set 14 | moron
# Processing Record 14 of Set 14 | honningsvag
# Processing Record 15 of Set 14 | inuvik
# Processing Record 16 of Set 14 | tiznit
# Processing Record 17 of Set 14 | luanda
# Processing Record 18 of Set 14 | jiwani
# Processing Record 19 of Set 14 | gazni
# City not found. Skipping...
# Processing Record 20 of Set 14 | kieta
# Processing Record 21 of Set 14 | zabaykalsk
# Processing Record 22 of Set 14 | birao
# Processing Record 23 of Set 14 | wladyslawowo
# Processing Record 24 of Set 14 | nambucca heads
# Processing Record 25 of Set 14 | puerto asis
# Processing Record 26 of Set 14 | port-gentil
# Processing Record 27 of Set 14 | cururupu
# Processing Record 28 of Set 14 | svetlogorsk
# Processing Record 29 of Set 14 | los llanos de aridane
# Processing Record 30 of Set 14 | angatuba
# Processing Record 31 of Set 14 | pangnirtung
# Processing Record 32 of Set 14 | dodoma
# Processing Record 33 of Set 14 | kajiado
# Processing Record 34 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 14 | mizdah
# Processing Record 36 of Set 14 | copperas cove
# Processing Record 37 of Set 14 | ratnapura
# Processing Record 38 of Set 14 | nova olinda do norte
# Processing Record 39 of Set 14 | carmo do rio verde
# Processing Record 40 of Set 14 | isiro
# Processing Record 41 of Set 14 | bundaberg
# Processing Record 42 of Set 14 | vanderhoof
# Processing Record 43 of Set 14 | imbituba
# Processing Record 44 of Set 14 | xining
# Processing Record 45 of Set 14 | leshukonskoye
# Processing Record 46 of Set 14 | khandyga
# Processing Record 47 of Set 14 | vostok
# Processing Record 48 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 14 | bourail
# Processing Record 50 of Set 14 | eyl
# Processing Record 1 of Set 15 | san quintin
# Processing Record 2 of Set 15 | san cristobal
# Processing Record 3 of Set 15 | songea
# Processing Record 4 of Set 15 | conde
# Processing Record 5 of Set 15 | duz
# City not found. Skipping...
# Processing Record 6 of Set 15 | vedaranniyam
# City not found. Skipping...
# Processing Record 7 of Set 15 | aqtobe
# Processing Record 8 of Set 15 | chauk
# Processing Record 9 of Set 15 | tomatlan
# Processing Record 10 of Set 15 | fuerte olimpo
# Processing Record 11 of Set 15 | amahai
# Processing Record 12 of Set 15 | aurillac
# Processing Record 13 of Set 15 | presidente epitacio
# Processing Record 14 of Set 15 | margate
# Processing Record 15 of Set 15 | umm kaddadah
# Processing Record 16 of Set 15 | nouadhibou
# Processing Record 17 of Set 15 | asau
# Processing Record 18 of Set 15 | te anau
# Processing Record 19 of Set 15 | nago
# Processing Record 20 of Set 15 | port lincoln
# Processing Record 21 of Set 15 | saintes
# Processing Record 22 of Set 15 | port hedland
# Processing Record 23 of Set 15 | san matias
# Processing Record 24 of Set 15 | san jose
# Processing Record 25 of Set 15 | sindor
# Processing Record 26 of Set 15 | san luis
# Processing Record 27 of Set 15 | macia
# Processing Record 28 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 15 | atka
# City not found. Skipping...
# Processing Record 30 of Set 15 | san carlos de bariloche
# Processing Record 31 of Set 15 | normandin
# Processing Record 32 of Set 15 | onokhoy
# Processing Record 33 of Set 15 | tabou
# Processing Record 34 of Set 15 | amurzet
# Processing Record 35 of Set 15 | livingston
# Processing Record 36 of Set 15 | srednekolymsk
# Processing Record 37 of Set 15 | mormugao
# Processing Record 38 of Set 15 | shakhtinsk
# Processing Record 39 of Set 15 | carbonia
# Processing Record 40 of Set 15 | pyapon
# Processing Record 41 of Set 15 | taybad
# Processing Record 42 of Set 15 | sharjah
# Processing Record 43 of Set 15 | mareeba
# Processing Record 44 of Set 15 | fallon
# Processing Record 45 of Set 15 | ekuvukeni
# Processing Record 46 of Set 15 | keetmanshoop
# Processing Record 47 of Set 15 | griffith
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Saskylakh  71.9167  114.0833     32.72        78          88       16.73
# 1        Say  13.1007    2.3689     77.56        87          63       12.33
# 2        Fez  34.0372   -4.9998     70.05        77          40        4.61
# 3    Batagay  67.6333  134.6333     35.53        64          94        4.12
# 4    Tarakan   3.3000  117.6333     85.50        70          20        5.75
# 5     Bethel  41.3712  -73.4140     66.49        87          40        0.00
# 6     Marawi   7.9986  124.2928     80.26        70          48        3.49
# 7  Jamestown  42.0970  -79.2353     65.79        71          75        8.05
# 8    Huainan  32.6264  116.9969     69.17        45         100        8.97
# 9    Ushuaia -54.8000  -68.3000     37.06        81           0        3.44
#
#   Country                 Date
# 0      RU  2022-09-20 05:46:51
# 1      NE  2022-09-20 05:46:51
# 2      MA  2022-09-20 05:46:51
# 3      RU  2022-09-20 05:46:52
# 4      ID  2022-09-20 05:46:52
# 5      US  2022-09-20 05:46:53
# 6      PH  2022-09-20 05:46:53
# 7      US  2022-09-20 05:46:54
# 8      CN  2022-09-20 05:46:54
# 9      AR  2022-09-20 05:46:54

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
