# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | garowe
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | sao jose da coroa grande
# Processing Record 13 of Set 1 | parkes
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | tutubigan
# Processing Record 21 of Set 1 | margate
# Processing Record 22 of Set 1 | hofn
# Processing Record 23 of Set 1 | tessalit
# Processing Record 24 of Set 1 | gornopravdinsk
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | constitucion
# Processing Record 27 of Set 1 | ailigandi
# Processing Record 28 of Set 1 | nuuk
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | sobolevo
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 1 | kavaratti
# Processing Record 37 of Set 1 | puerto quijarro
# Processing Record 38 of Set 1 | yulara
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | trairi
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | sanmenxia
# Processing Record 46 of Set 1 | rensvik
# Processing Record 47 of Set 1 | olafsvik
# Processing Record 48 of Set 1 | touros
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | port said
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | kudymkar
# Processing Record 7 of Set 2 | vanavara
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | santa marta
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | charlestown
# Processing Record 17 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 2 | luanda
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | gat
# Processing Record 21 of Set 2 | catalao
# Processing Record 22 of Set 2 | pareora
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | evensk
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | maralal
# Processing Record 28 of Set 2 | olinda
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | oussouye
# Processing Record 31 of Set 2 | urumqi
# Processing Record 32 of Set 2 | ken caryl
# Processing Record 33 of Set 2 | lata
# Processing Record 34 of Set 2 | narsaq
# Processing Record 35 of Set 2 | conde
# Processing Record 36 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 2 | lypnyazhka
# Processing Record 38 of Set 2 | iwanai
# Processing Record 39 of Set 2 | mayo
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | santa rosa
# Processing Record 42 of Set 2 | bajil
# Processing Record 43 of Set 2 | biak
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | moerai
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | mehamn
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | la palma
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | kidal
# Processing Record 6 of Set 3 | severo-yeniseyskiy
# Processing Record 7 of Set 3 | tayzhina
# Processing Record 8 of Set 3 | san-pedro
# Processing Record 9 of Set 3 | emerald
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | hovd
# Processing Record 12 of Set 3 | charters towers
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | palana
# Processing Record 15 of Set 3 | chifeng
# Processing Record 16 of Set 3 | fairbanks
# Processing Record 17 of Set 3 | balasinor
# City not found. Skipping...
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | shitkino
# Processing Record 20 of Set 3 | coos bay
# Processing Record 21 of Set 3 | stratford
# Processing Record 22 of Set 3 | tabriz
# Processing Record 23 of Set 3 | georgiyevka
# Processing Record 24 of Set 3 | dingle
# Processing Record 25 of Set 3 | puerto baquerizo moreno
# Processing Record 26 of Set 3 | samarai
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 3 | sao gabriel da cachoeira
# Processing Record 32 of Set 3 | tuatapere
# Processing Record 33 of Set 3 | vitim
# Processing Record 34 of Set 3 | merauke
# Processing Record 35 of Set 3 | chulym
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | aljezur
# Processing Record 39 of Set 3 | marawi
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | lincoln
# Processing Record 42 of Set 3 | wanaka
# Processing Record 43 of Set 3 | ketchikan
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 3 | lokoja
# Processing Record 47 of Set 3 | impfondo
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | vaini
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | takoradi
# Processing Record 4 of Set 4 | pitea
# Processing Record 5 of Set 4 | timra
# Processing Record 6 of Set 4 | mahibadhoo
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | berlevag
# Processing Record 9 of Set 4 | veraval
# Processing Record 10 of Set 4 | labuhan
# Processing Record 11 of Set 4 | ayan
# Processing Record 12 of Set 4 | dikson
# Processing Record 13 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 4 | nanortalik
# Processing Record 15 of Set 4 | meulaboh
# Processing Record 16 of Set 4 | nandurbar
# Processing Record 17 of Set 4 | kapiri mposhi
# Processing Record 18 of Set 4 | yumen
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | russell
# Processing Record 21 of Set 4 | severobaykalsk
# Processing Record 22 of Set 4 | cascais
# Processing Record 23 of Set 4 | great falls
# Processing Record 24 of Set 4 | summerland
# Processing Record 25 of Set 4 | nyurba
# Processing Record 26 of Set 4 | palmares do sul
# Processing Record 27 of Set 4 | kutum
# Processing Record 28 of Set 4 | sorland
# Processing Record 29 of Set 4 | mana
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | torbay
# Processing Record 32 of Set 4 | jumla
# Processing Record 33 of Set 4 | syracuse
# Processing Record 34 of Set 4 | fare
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | cherskiy
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | porto nacional
# Processing Record 40 of Set 4 | bacungan
# Processing Record 41 of Set 4 | turtas
# Processing Record 42 of Set 4 | havelock
# Processing Record 43 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | cockburn town
# Processing Record 46 of Set 4 | trinidad
# Processing Record 47 of Set 4 | naze
# Processing Record 48 of Set 4 | ouesso
# Processing Record 49 of Set 4 | chirongui
# Processing Record 50 of Set 4 | vestmanna
# Processing Record 1 of Set 5 | yellowknife
# Processing Record 2 of Set 5 | peleduy
# Processing Record 3 of Set 5 | huarmey
# Processing Record 4 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 5 of Set 5 | visnes
# Processing Record 6 of Set 5 | waipawa
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | thinadhoo
# Processing Record 9 of Set 5 | srandakan
# Processing Record 10 of Set 5 | zarautz
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | lebowakgomo
# Processing Record 13 of Set 5 | san onofre
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | cepu
# Processing Record 16 of Set 5 | pangnirtung
# Processing Record 17 of Set 5 | te karaka
# Processing Record 18 of Set 5 | ileza
# Processing Record 19 of Set 5 | port elizabeth
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | zeya
# Processing Record 22 of Set 5 | dudinka
# Processing Record 23 of Set 5 | tendo
# Processing Record 24 of Set 5 | gaoua
# Processing Record 25 of Set 5 | ye
# City not found. Skipping...
# Processing Record 26 of Set 5 | acarau
# Processing Record 27 of Set 5 | bukama
# Processing Record 28 of Set 5 | koumra
# Processing Record 29 of Set 5 | madras
# Processing Record 30 of Set 5 | ayer itam
# City not found. Skipping...
# Processing Record 31 of Set 5 | suhbaatar
# Processing Record 32 of Set 5 | hualmay
# Processing Record 33 of Set 5 | itarema
# Processing Record 34 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 35 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 5 | coihaique
# Processing Record 37 of Set 5 | srednekolymsk
# Processing Record 38 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 5 | yaan
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | dahuk
# Processing Record 42 of Set 5 | mecca
# Processing Record 43 of Set 5 | hami
# Processing Record 44 of Set 5 | calbuco
# Processing Record 45 of Set 5 | khor
# Processing Record 46 of Set 5 | ahipara
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | poum
# Processing Record 49 of Set 5 | ossora
# Processing Record 50 of Set 5 | honningsvag
# Processing Record 1 of Set 6 | cedar city
# Processing Record 2 of Set 6 | kenai
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | marsa matruh
# Processing Record 5 of Set 6 | tazovskiy
# Processing Record 6 of Set 6 | barra patuca
# Processing Record 7 of Set 6 | sioux lookout
# Processing Record 8 of Set 6 | isangel
# Processing Record 9 of Set 6 | sisophon
# Processing Record 10 of Set 6 | akyab
# Processing Record 11 of Set 6 | saint-pierre
# Processing Record 12 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 6 | coaticook
# Processing Record 14 of Set 6 | paamiut
# Processing Record 15 of Set 6 | caravelas
# Processing Record 16 of Set 6 | yelizovo
# Processing Record 17 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 6 | mount isa
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | muros
# Processing Record 21 of Set 6 | viedma
# Processing Record 22 of Set 6 | whakatane
# Processing Record 23 of Set 6 | nador
# Processing Record 24 of Set 6 | puerto escondido
# Processing Record 25 of Set 6 | karratha
# Processing Record 26 of Set 6 | kruisfontein
# Processing Record 27 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 6 | saint george
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | lamar
# Processing Record 31 of Set 6 | basoko
# Processing Record 32 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | henties bay
# Processing Record 35 of Set 6 | kasongo-lunda
# Processing Record 36 of Set 6 | yishui
# Processing Record 37 of Set 6 | te anau
# Processing Record 38 of Set 6 | emba
# Processing Record 39 of Set 6 | harper
# Processing Record 40 of Set 6 | fort stewart
# Processing Record 41 of Set 6 | bereda
# Processing Record 42 of Set 6 | hermanus
# Processing Record 43 of Set 6 | lebu
# Processing Record 44 of Set 6 | alzamay
# Processing Record 45 of Set 6 | san cristobal
# Processing Record 46 of Set 6 | tiarei
# Processing Record 47 of Set 6 | quang ngai
# Processing Record 48 of Set 6 | chitrakonda
# Processing Record 49 of Set 6 | georgetown
# Processing Record 50 of Set 6 | bethel
# Processing Record 1 of Set 7 | flinders
# Processing Record 2 of Set 7 | songjianghe
# Processing Record 3 of Set 7 | japura
# Processing Record 4 of Set 7 | egvekinot
# Processing Record 5 of Set 7 | alice springs
# Processing Record 6 of Set 7 | carauari
# Processing Record 7 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | tezu
# Processing Record 9 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 7 | guinticgan
# Processing Record 11 of Set 7 | deputatskiy
# Processing Record 12 of Set 7 | ormara
# Processing Record 13 of Set 7 | shaowu
# Processing Record 14 of Set 7 | tazmalt
# Processing Record 15 of Set 7 | itoman
# Processing Record 16 of Set 7 | sinnamary
# Processing Record 17 of Set 7 | barra do garcas
# Processing Record 18 of Set 7 | korla
# Processing Record 19 of Set 7 | lagoa
# Processing Record 20 of Set 7 | westport
# Processing Record 21 of Set 7 | mezen
# Processing Record 22 of Set 7 | chara
# Processing Record 23 of Set 7 | dongsheng
# Processing Record 24 of Set 7 | nishihara
# Processing Record 25 of Set 7 | nebolchi
# Processing Record 26 of Set 7 | godfrey
# Processing Record 27 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 7 | trofors
# Processing Record 30 of Set 7 | tahe
# Processing Record 31 of Set 7 | nueva gerona
# Processing Record 32 of Set 7 | quelimane
# Processing Record 33 of Set 7 | jinchang
# Processing Record 34 of Set 7 | gamba
# Processing Record 35 of Set 7 | grindavik
# Processing Record 36 of Set 7 | sistranda
# Processing Record 37 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 38 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 39 of Set 7 | ondangwa
# Processing Record 40 of Set 7 | cayenne
# Processing Record 41 of Set 7 | nome
# Processing Record 42 of Set 7 | dubti
# Processing Record 43 of Set 7 | poya
# Processing Record 44 of Set 7 | antofagasta
# Processing Record 45 of Set 7 | tilichiki
# Processing Record 46 of Set 7 | mersing
# Processing Record 47 of Set 7 | donskoye
# Processing Record 48 of Set 7 | kimbe
# Processing Record 49 of Set 7 | kiunga
# Processing Record 50 of Set 7 | yuzhou
# Processing Record 1 of Set 8 | leibnitz
# Processing Record 2 of Set 8 | walvis bay
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | bridlington
# Processing Record 5 of Set 8 | mahebourg
# Processing Record 6 of Set 8 | ugoofaaru
# Processing Record 7 of Set 8 | reefton
# City not found. Skipping...
# Processing Record 8 of Set 8 | bontang
# Processing Record 9 of Set 8 | parapotamos
# Processing Record 10 of Set 8 | matara
# Processing Record 11 of Set 8 | lorengau
# Processing Record 12 of Set 8 | verkhoyansk
# Processing Record 13 of Set 8 | yangambi
# Processing Record 14 of Set 8 | tourlaville
# Processing Record 15 of Set 8 | bani walid
# Processing Record 16 of Set 8 | naliya
# Processing Record 17 of Set 8 | estevan
# Processing Record 18 of Set 8 | bloemfontein
# Processing Record 19 of Set 8 | galle
# Processing Record 20 of Set 8 | fostoria
# Processing Record 21 of Set 8 | sao felix do xingu
# Processing Record 22 of Set 8 | mar del plata
# Processing Record 23 of Set 8 | mayumba
# Processing Record 24 of Set 8 | axim
# Processing Record 25 of Set 8 | bathsheba
# Processing Record 26 of Set 8 | paita
# Processing Record 27 of Set 8 | longfeng
# Processing Record 28 of Set 8 | saint anthony
# Processing Record 29 of Set 8 | sol-iletsk
# Processing Record 30 of Set 8 | kitimat
# Processing Record 31 of Set 8 | mae hong son
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | luena
# Processing Record 34 of Set 8 | amapa
# Processing Record 35 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 8 | alofi
# Processing Record 37 of Set 8 | omboue
# Processing Record 38 of Set 8 | kieta
# Processing Record 39 of Set 8 | addanki
# Processing Record 40 of Set 8 | mount pleasant
# Processing Record 41 of Set 8 | port hardy
# Processing Record 42 of Set 8 | sun prairie
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | roald
# Processing Record 45 of Set 8 | rocha
# Processing Record 46 of Set 8 | havre
# Processing Record 47 of Set 8 | zakamensk
# Processing Record 48 of Set 8 | bud
# Processing Record 49 of Set 8 | kargasok
# Processing Record 50 of Set 8 | esna
# Processing Record 1 of Set 9 | dasoguz
# Processing Record 2 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 9 | alizai
# Processing Record 4 of Set 9 | tucuma
# Processing Record 5 of Set 9 | mantua
# Processing Record 6 of Set 9 | launceston
# Processing Record 7 of Set 9 | newton
# Processing Record 8 of Set 9 | mananjary
# Processing Record 9 of Set 9 | zabaykalsk
# Processing Record 10 of Set 9 | zhezkazgan
# Processing Record 11 of Set 9 | batticaloa
# Processing Record 12 of Set 9 | aban
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | san juan
# Processing Record 15 of Set 9 | pamekasan
# Processing Record 16 of Set 9 | kikwit
# Processing Record 17 of Set 9 | sao joao da barra
# Processing Record 18 of Set 9 | talnakh
# Processing Record 19 of Set 9 | manikpur
# Processing Record 20 of Set 9 | laredo
# Processing Record 21 of Set 9 | miles city
# Processing Record 22 of Set 9 | kouango
# Processing Record 23 of Set 9 | baghdad
# Processing Record 24 of Set 9 | puerto parra
# Processing Record 25 of Set 9 | fort saint james
# Processing Record 26 of Set 9 | dalinghe
# City not found. Skipping...
# Processing Record 27 of Set 9 | jhargram
# Processing Record 28 of Set 9 | sorong
# Processing Record 29 of Set 9 | bakel
# Processing Record 30 of Set 9 | bejar
# Processing Record 31 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 32 of Set 9 | quixeramobim
# Processing Record 33 of Set 9 | aleksandrov gay
# Processing Record 34 of Set 9 | ouadda
# Processing Record 35 of Set 9 | havre-saint-pierre
# Processing Record 36 of Set 9 | moquegua
# Processing Record 37 of Set 9 | gualeguay
# Processing Record 38 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 9 | mustasaari
# Processing Record 40 of Set 9 | mbuji-mayi
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | urulga
# City not found. Skipping...
# Processing Record 43 of Set 9 | mus
# Processing Record 44 of Set 9 | santa isabel do rio negro
# Processing Record 45 of Set 9 | les escoumins
# Processing Record 46 of Set 9 | kashi
# Processing Record 47 of Set 9 | ribas do rio pardo
# Processing Record 48 of Set 9 | fort nelson
# Processing Record 49 of Set 9 | iacu
# Processing Record 50 of Set 9 | atka
# City not found. Skipping...
# Processing Record 1 of Set 10 | shenzhen
# Processing Record 2 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 3 of Set 10 | okhotsk
# Processing Record 4 of Set 10 | benghazi
# Processing Record 5 of Set 10 | mpongwe
# Processing Record 6 of Set 10 | kachug
# Processing Record 7 of Set 10 | muzaffarabad
# Processing Record 8 of Set 10 | ambovombe
# Processing Record 9 of Set 10 | inverness
# Processing Record 10 of Set 10 | columbus
# Processing Record 11 of Set 10 | port lincoln
# Processing Record 12 of Set 10 | qaqortoq
# Processing Record 13 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 10 | jinxiang
# Processing Record 15 of Set 10 | dubovka
# Processing Record 16 of Set 10 | denpasar
# Processing Record 17 of Set 10 | laguna
# Processing Record 18 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 19 of Set 10 | gisors
# Processing Record 20 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 21 of Set 10 | gigmoto
# Processing Record 22 of Set 10 | qarayeri
# Processing Record 23 of Set 10 | morro bay
# Processing Record 24 of Set 10 | bestobe
# Processing Record 25 of Set 10 | skegness
# Processing Record 26 of Set 10 | misratah
# Processing Record 27 of Set 10 | yerbogachen
# Processing Record 28 of Set 10 | champasak
# Processing Record 29 of Set 10 | kapuskasing
# Processing Record 30 of Set 10 | dawson creek
# Processing Record 31 of Set 10 | grand-santi
# Processing Record 32 of Set 10 | yangjiang
# Processing Record 33 of Set 10 | abhar
# Processing Record 34 of Set 10 | hobyo
# Processing Record 35 of Set 10 | kilembe
# Processing Record 36 of Set 10 | nieuwpoort
# Processing Record 37 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 10 | manaure
# Processing Record 39 of Set 10 | ullapool
# Processing Record 40 of Set 10 | lima
# Processing Record 41 of Set 10 | ambon
# Processing Record 42 of Set 10 | nanchong
# Processing Record 43 of Set 10 | simplicio mendes
# Processing Record 44 of Set 10 | kirksville
# Processing Record 45 of Set 10 | ballina
# Processing Record 46 of Set 10 | funadhoo
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | knoxville
# Processing Record 49 of Set 10 | muqui
# Processing Record 50 of Set 10 | shingu
# Processing Record 1 of Set 11 | agadez
# Processing Record 2 of Set 11 | kotido
# Processing Record 3 of Set 11 | los llanos de aridane
# Processing Record 4 of Set 11 | zhangye
# Processing Record 5 of Set 11 | kargopol
# Processing Record 6 of Set 11 | west bay
# Processing Record 7 of Set 11 | liberal
# Processing Record 8 of Set 11 | sterling
# Processing Record 9 of Set 11 | mama
# Processing Record 10 of Set 11 | iracoubo
# Processing Record 11 of Set 11 | tautira
# Processing Record 12 of Set 11 | ceres
# Processing Record 13 of Set 11 | athabasca
# Processing Record 14 of Set 11 | marsh harbour
# Processing Record 15 of Set 11 | avera
# Processing Record 16 of Set 11 | cao bang
# Processing Record 17 of Set 11 | chalchihuites
# Processing Record 18 of Set 11 | dandong
# Processing Record 19 of Set 11 | el tigre
# Processing Record 20 of Set 11 | varhaug
# Processing Record 21 of Set 11 | blythe
# Processing Record 22 of Set 11 | jalu
# Processing Record 23 of Set 11 | mbandaka
# Processing Record 24 of Set 11 | saldanha
# Processing Record 25 of Set 11 | laya
# Processing Record 26 of Set 11 | vagur
# Processing Record 27 of Set 11 | tres passos
# Processing Record 28 of Set 11 | barzas
# Processing Record 29 of Set 11 | seddon
# Processing Record 30 of Set 11 | glendive
# Processing Record 31 of Set 11 | nettuno
# Processing Record 32 of Set 11 | nyagan
# Processing Record 33 of Set 11 | menongue
# Processing Record 34 of Set 11 | port augusta
# Processing Record 35 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 11 | xuddur
# Processing Record 37 of Set 11 | turukhansk
# Processing Record 38 of Set 11 | mwingi
# Processing Record 39 of Set 11 | beian
# Processing Record 40 of Set 11 | north bend
# Processing Record 41 of Set 11 | flin flon
# Processing Record 42 of Set 11 | acapulco
# Processing Record 43 of Set 11 | chapais
# Processing Record 44 of Set 11 | victor harbor
# Processing Record 45 of Set 11 | aswan
# Processing Record 46 of Set 11 | marathon
# Processing Record 47 of Set 11 | bima
# Processing Record 48 of Set 11 | karangsembung
# Processing Record 49 of Set 11 | yaring
# Processing Record 50 of Set 11 | gornyy
# Processing Record 1 of Set 12 | nouadhibou
# Processing Record 2 of Set 12 | ewa beach
# Processing Record 3 of Set 12 | borogontsy
# Processing Record 4 of Set 12 | el bagre
# Processing Record 5 of Set 12 | hokitika
# Processing Record 6 of Set 12 | shinuhayr
# Processing Record 7 of Set 12 | catacamas
# Processing Record 8 of Set 12 | longido
# Processing Record 9 of Set 12 | asau
# Processing Record 10 of Set 12 | rawlins
# Processing Record 11 of Set 12 | siderno
# Processing Record 12 of Set 12 | hamilton
# Processing Record 13 of Set 12 | ust-nera
# Processing Record 14 of Set 12 | tura
# Processing Record 15 of Set 12 | leningradskiy
# Processing Record 16 of Set 12 | monrovia
# Processing Record 17 of Set 12 | champerico
# Processing Record 18 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 12 | nampula
# Processing Record 20 of Set 12 | subottsi
# Processing Record 21 of Set 12 | abnub
# Processing Record 22 of Set 12 | ust-kuyga
# Processing Record 23 of Set 12 | east stroudsburg
# Processing Record 24 of Set 12 | la rochelle
# Processing Record 25 of Set 12 | straumen
# Processing Record 26 of Set 12 | suhut
# Processing Record 27 of Set 12 | faanui
# Processing Record 28 of Set 12 | san ramon
# Processing Record 29 of Set 12 | chekhov
# Processing Record 30 of Set 12 | pandan
# Processing Record 31 of Set 12 | havoysund
# Processing Record 32 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 12 | mount gambier
# Processing Record 35 of Set 12 | guzdak
# City not found. Skipping...
# Processing Record 36 of Set 12 | florianopolis
# Processing Record 37 of Set 12 | bagdarin
# Processing Record 38 of Set 12 | oranjemund
# Processing Record 39 of Set 12 | korhogo
# Processing Record 40 of Set 12 | lazaro cardenas
# Processing Record 41 of Set 12 | kyshtovka
# Processing Record 42 of Set 12 | hirado
# Processing Record 43 of Set 12 | winslow
# Processing Record 44 of Set 12 | navoi
# Processing Record 45 of Set 12 | pundaguitan
# Processing Record 46 of Set 12 | paragould
# Processing Record 47 of Set 12 | whitianga
# Processing Record 48 of Set 12 | abapo
# Processing Record 49 of Set 12 | martinsburg
# Processing Record 50 of Set 12 | cortez
# Processing Record 1 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 2 of Set 13 | sapao
# City not found. Skipping...
# Processing Record 3 of Set 13 | azrow
# City not found. Skipping...
# Processing Record 4 of Set 13 | jacmel
# Processing Record 5 of Set 13 | banyumas
# Processing Record 6 of Set 13 | shizunai
# Processing Record 7 of Set 13 | gore
# Processing Record 8 of Set 13 | terrenate
# Processing Record 9 of Set 13 | vavozh
# Processing Record 10 of Set 13 | talitsa
# Processing Record 11 of Set 13 | port blair
# Processing Record 12 of Set 13 | aykhal
# Processing Record 13 of Set 13 | amarante do maranhao
# Processing Record 14 of Set 13 | pangkalanbuun
# Processing Record 15 of Set 13 | ola
# Processing Record 16 of Set 13 | port hedland
# Processing Record 17 of Set 13 | pospelikha
# Processing Record 18 of Set 13 | hilton head island
# Processing Record 19 of Set 13 | araouane
# Processing Record 20 of Set 13 | jais
# Processing Record 21 of Set 13 | trzebiatow
# Processing Record 22 of Set 13 | chimbote
# Processing Record 23 of Set 13 | gazojak
# Processing Record 24 of Set 13 | kamaishi
# Processing Record 25 of Set 13 | sarandi
# Processing Record 26 of Set 13 | jackson
# Processing Record 27 of Set 13 | valley city
# Processing Record 28 of Set 13 | vaitape
# Processing Record 29 of Set 13 | novaya igirma
# Processing Record 30 of Set 13 | opuwo
# Processing Record 31 of Set 13 | vigrestad
# Processing Record 32 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 13 | kochevo
# Processing Record 34 of Set 13 | beringovskiy
# Processing Record 35 of Set 13 | puerto ayacucho
# Processing Record 36 of Set 13 | saryagash
# Processing Record 37 of Set 13 | apartado
# Processing Record 38 of Set 13 | ulyanovo
# City not found. Skipping...
# Processing Record 39 of Set 13 | pochutla
# Processing Record 40 of Set 13 | vondrozo
# Processing Record 41 of Set 13 | mazagao
# Processing Record 42 of Set 13 | riyadh
# Processing Record 43 of Set 13 | pierre
# Processing Record 44 of Set 13 | luderitz
# Processing Record 45 of Set 13 | vila do maio
# Processing Record 46 of Set 13 | langxiang
# Processing Record 47 of Set 13 | sept-iles
# Processing Record 48 of Set 13 | yamada
# Processing Record 49 of Set 13 | bandarbeyla
# Processing Record 50 of Set 13 | isilkul
# Processing Record 1 of Set 14 | abong mbang
# Processing Record 2 of Set 14 | melilla
# Processing Record 3 of Set 14 | sibiti
# Processing Record 4 of Set 14 | kyra
# Processing Record 5 of Set 14 | concepcion del oro
# Processing Record 6 of Set 14 | teguldet
# Processing Record 7 of Set 14 | kloulklubed
# Processing Record 8 of Set 14 | ferme-neuve
# Processing Record 9 of Set 14 | kathmandu
# Processing Record 10 of Set 14 | canon city
# Processing Record 11 of Set 14 | svetlaya
# Processing Record 12 of Set 14 | kununurra
# Processing Record 13 of Set 14 | rizhao
# Processing Record 14 of Set 14 | karwar
# Processing Record 15 of Set 14 | fremont
# Processing Record 16 of Set 14 | bonthe
# Processing Record 17 of Set 14 | moose factory
# Processing Record 18 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 14 | catia la mar
# Processing Record 20 of Set 14 | waingapu
# Processing Record 21 of Set 14 | nueva helvecia
# Processing Record 22 of Set 14 | la libertad
# Processing Record 23 of Set 14 | morgan city
# Processing Record 24 of Set 14 | begoro
# Processing Record 25 of Set 14 | kandrian
# Processing Record 26 of Set 14 | tiznit
# Processing Record 27 of Set 14 | maragogi
# Processing Record 28 of Set 14 | martaban
# Processing Record 29 of Set 14 | port moresby
# Processing Record 30 of Set 14 | gorin
# Processing Record 31 of Set 14 | kirakira
# Processing Record 32 of Set 14 | rincon
# Processing Record 33 of Set 14 | bisceglie
# Processing Record 34 of Set 14 | san policarpo
# Processing Record 35 of Set 14 | eirunepe
# Processing Record 36 of Set 14 | smithers
# Processing Record 37 of Set 14 | matagami
# Processing Record 38 of Set 14 | anadyr
# Processing Record 39 of Set 14 | uruzgan
# Processing Record 40 of Set 14 | lingdong
# Processing Record 41 of Set 14 | porto novo
# Processing Record 42 of Set 14 | onojo
# Processing Record 43 of Set 14 | carndonagh
# Processing Record 44 of Set 14 | swellendam
# Processing Record 45 of Set 14 | atbasar
# Processing Record 46 of Set 14 | vuktyl
# Processing Record 47 of Set 14 | nouakchott
# Processing Record 48 of Set 14 | xining
# Processing Record 49 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 50 of Set 14 | alugan
# Processing Record 1 of Set 15 | rawson
# Processing Record 2 of Set 15 | ibra
# Processing Record 3 of Set 15 | neuquen
# Processing Record 4 of Set 15 | mabai
# Processing Record 5 of Set 15 | nizhneangarsk
# Processing Record 6 of Set 15 | zhaocheng
# City not found. Skipping...
# Processing Record 7 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 15 | parati
# Processing Record 9 of Set 15 | luganville
# Processing Record 10 of Set 15 | cairns
# Processing Record 11 of Set 15 | xapuri
# Processing Record 12 of Set 15 | aripuana
# Processing Record 13 of Set 15 | port keats
# Processing Record 14 of Set 15 | les cayes
# Processing Record 15 of Set 15 | vostok
# Processing Record 16 of Set 15 | sibu
# Processing Record 17 of Set 15 | uzhur
# Processing Record 18 of Set 15 | kologriv
# Processing Record 19 of Set 15 | banepa
# Processing Record 20 of Set 15 | cleburne
# Processing Record 21 of Set 15 | bambanglipuro
# Processing Record 22 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 15 | saint-denis
# Processing Record 24 of Set 15 | palmer
# Processing Record 25 of Set 15 | arman
# Processing Record 26 of Set 15 | saint-paul
# Processing Record 27 of Set 15 | ambulu
# Processing Record 28 of Set 15 | chaa-khol
# City not found. Skipping...
# Processing Record 29 of Set 15 | krasnoselkup
# Processing Record 30 of Set 15 | wajir
# Processing Record 31 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 15 | bac lieu
# Processing Record 33 of Set 15 | bongandanga
# Processing Record 34 of Set 15 | vichayal
# City not found. Skipping...
# Processing Record 35 of Set 15 | neiafu
# Processing Record 36 of Set 15 | fengzhen
# Processing Record 37 of Set 15 | kanelovskaya
# Processing Record 38 of Set 15 | urucui
# Processing Record 39 of Set 15 | broken hill
# Processing Record 40 of Set 15 | cam ranh
# Processing Record 41 of Set 15 | boa vista
# Processing Record 42 of Set 15 | vao
# Processing Record 43 of Set 15 | carbonia
# Processing Record 44 of Set 15 | the valley
# Processing Record 45 of Set 15 | shieli
# Processing Record 46 of Set 15 | djambala
# Processing Record 47 of Set 15 | kiama
# Processing Record 48 of Set 15 | aqtobe
# Processing Record 49 of Set 15 | buraydah
# Processing Record 50 of Set 15 | damietta
# Processing Record 1 of Set 16 | dzilam gonzalez
# Processing Record 2 of Set 16 | wloszczowa
# Processing Record 3 of Set 16 | vytegra
# Processing Record 4 of Set 16 | killybegs
# Processing Record 5 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 16 | tombouctou
# Processing Record 7 of Set 16 | siruguppa
# Processing Record 8 of Set 16 | kjollefjord
# Processing Record 9 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 16 | jian
# Processing Record 11 of Set 16 | rawannawi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0        Garowe   8.4054   48.4845     74.86          few clouds        58
# 1       Rikitea -23.1203 -134.9692     74.50     overcast clouds        87
# 2    Vila Velha -20.3297  -40.2925     76.95     overcast clouds        91
# 3   New Norfolk -42.7826  147.0587     56.91       moderate rain        75
# 4       Ushuaia -54.8000  -68.3000     55.06           clear sky        50
# 5         Vardo  70.3705   31.1107     31.98       broken clouds        80
# 6  Punta Arenas -53.1500  -70.9167     55.51           clear sky        82
# 7     Cape Town -33.9258   18.4232     65.91           clear sky        69
# 8     Saskylakh  71.9167  114.0833     -7.71     overcast clouds        95
# 9        Castro -24.7911  -50.0119     60.75     overcast clouds        98
#
#    Cloudiness  Wind Speed Country                 Date
# 0          16       10.31      SO  2022-11-14 05:13:17
# 1          98       12.82      PF  2022-11-14 05:13:18
# 2         100       11.99      BR  2022-11-14 05:13:19
# 3         100        4.00      AU  2022-11-14 05:13:19
# 4           0        9.22      AR  2022-11-14 05:13:20
# 5          75        9.22      NO  2022-11-14 05:13:20
# 6           0        4.61      CL  2022-11-14 05:13:21
# 7           0        4.61      ZA  2022-11-14 05:13:21
# 8         100       12.21      RU  2022-11-14 05:13:22
# 9         100        2.95      BR  2022-11-14 05:13:23

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Garowe   8.4054   48.4845     74.86          few clouds        58
# 1      Rikitea -23.1203 -134.9692     74.50     overcast clouds        87
# 2   Vila Velha -20.3297  -40.2925     76.95     overcast clouds        91
# 3  New Norfolk -42.7826  147.0587     56.91       moderate rain        75
# 4      Ushuaia -54.8000  -68.3000     55.06           clear sky        50
#
#    Cloudiness  Wind Speed Country                 Date
# 0          16       10.31      SO  2022-11-14 05:13:17
# 1          98       12.82      PF  2022-11-14 05:13:18
# 2         100       11.99      BR  2022-11-14 05:13:19
# 3         100        4.00      AU  2022-11-14 05:13:19
# 4           0        9.22      AR  2022-11-14 05:13:20
